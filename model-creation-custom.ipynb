# %%
import spacy
from spacy import displacy
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm
import pandas as pd
import json
from spacy.util import filter_spans #to idenify overlapping entities

# %%
nlp = spacy.load("en_core_web_lg")
doc = nlp("hello i am dev")
 
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">hello i am
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dev
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>

# %%
string = "Antiretroviral therapy ( ART ) is recommended for all HIV-infected individuals"
doc = nlp(string)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Antiretroviral therapy ( ART ) is recommended for all HIV-infected individuals</div></span>

# %%
data = pd.read_csv('../../datasets/ncbi-disease/traindata.csv')

# %%
data
# Out:
#                                                   text  \
# 0    Identification of APC2  a homologue of the  ad...
# 1    A common MSH2 mutation in English and North Am...
# 2    Age of onset in  Huntington disease    sex spe...
# 3    Familial deficiency of the seventh component o...
# 4    Increased incidence of  cancer  in patients wi...
# ..                                                 ...
# 788  atm and p53 cooperate in apoptosis and suppres...
# 789  Trinucleotide repeat expansion at the  myotoni...
# 790  Constitutively methylated CpG dinucleotides as...
# 791  The  von Hippel Lindau tumor  suppressor gene ...
# 792  Adult onset globoid cell leukodystrophy    Kra...
#
#                                               entities
# 0    {"entities": [[1131, 1137, "SpecificDisease"],...
# 1    {"entities": [[135, 152, "SpecificDisease"], [...
# 2    {"entities": [[169, 171, "SpecificDisease"], [...
# 3    {"entities": [[0, 58, "SpecificDisease"], [146...
# ...

# %%
#data format = [(text,entities)]

train_data  = [] 

for i in range(len(data)):
    dic = json.loads(data.iloc[i].entities)
    toTup = [tuple(lst) for lst in dic['entities']]
    tup = {'text' : data.iloc[i].text ,'entities' : toTup }
    train_data.append(tup)

# %%
nlp = spacy.blank("en") # load a new spacy model
doc_bin = DocBin() # create a DocBin object

# %%
for training_example  in tqdm(train_data): 
    text = training_example['text']
    labels = training_example['entities']
    doc = nlp.make_doc(text) 
    ents = []
    for start, end, label in labels:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    filtered_ents = filter_spans(ents)
    doc.ents = filtered_ents 
    doc_bin.add(doc)

doc_bin.to_disk("../../datasets/training_data.spacy") # save the docbin object
# Out:
#  21%|████████████████████████████▎                                                                                                        | 169/793 [00:00<00:01, 581.99it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# ...

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# 2023-03-27 22:52:09.747095: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 22:52:09.839801: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-27 22:52:09.842247: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
# !python -m spacy train config.cfg --output ./ --paths.train ./training_data.spacy --paths.dev ./training_data.spacy
# Out:
# 2023-03-26 18:39:50.275252: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-26 18:39:50.368964: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-26 18:39:50.371411: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
def findEntity(text):
    nlp_ner = spacy.load("model-best")

    doc = nlp_ner(text)

    colors = {"SpecificDisease": "#F67DE3", "DiseaseClass": "#7DF6D9", "CompositeMention":"#FF3355","Modifier":"#68FF33"}
    options = {"colors": colors} 

    spacy.displacy.render(doc, style="ent", options= options, jupyter=True)

# %%
i = 0
for i in range(len(data)):
    findEntity(data.iloc[i].text)
    if i > 10:
        break
    i+=1
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Identification of APC2  a homologue of the
# <mark class="entity" style="background: ##5DADE2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adenomatous polyposis coli tumour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Modifier</span>
# </mark>
#   suppressor   The
# <mark class="entity" style="background: ##5DADE2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adenomatous polyposis coli   APC   tumour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Modifier</span>
# </mark>
# ...

# %%
nlp_ner = spacy.load("model-best")

doc = nlp_ner("")

colors = {"SpecificDisease": "#F67DE3", "DiseaseClass": "#7DF6D9", "CompositeMention":"#FFFFFF","Modifier":"#ffff05"}
options = {"colors": colors} 

spacy.displacy.render(doc, style="ent", options= options, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></div></span>

# %%
text = '''Cancer is a group of diseases characterized by the uncontrolled growth and spread of abnormal cells in the body. Cancer can occur in any part of the body and can spread to other parts through the blood and lymphatic systems. There are many different types of cancer, each with its own characteristics, symptoms, and treatment options.

Here are some of the most common types of cancer:

Breast Cancer: Breast cancer is the most common cancer in women worldwide. It occurs when abnormal cells in the breast tissue begin to grow and divide uncontrollably. Symptoms include a lump or thickening in the breast or underarm, nipple discharge or tenderness, and changes in the size or shape of the breast.

Lung Cancer: Lung cancer is the leading cause of cancer death worldwide. It occurs when abnormal cells in the lungs grow and divide uncontrollably. Symptoms include coughing, chest pain, shortness of breath, and wheezing.

Prostate Cancer: Prostate cancer is the most common cancer in men after skin cancer. It occurs when abnormal cells in the prostate gland begin to grow and divide uncontrollably. Symptoms include difficulty urinating, weak urine flow, blood in the urine, and erectile dysfunction.

Colorectal Cancer: Colorectal cancer is the third most common cancer worldwide. It occurs when abnormal cells in the colon or rectum grow and divide uncontrollably. Symptoms include abdominal pain, constipation, diarrhea, and rectal bleeding.

Skin Cancer: Skin cancer is the most common type of cancer in the United States. It occurs when abnormal cells in the skin grow and divide uncontrollably. Symptoms include changes in the color, size, or shape of a mole or other skin lesion, as well as sores that do not heal.

Leukemia: Leukemia is a type of blood cancer that affects the bone marrow and blood cells. It occurs when abnormal white blood cells grow and divide uncontrollably. Symptoms include fatigue, weakness, infections, and easy bleeding or bruising.

Lymphoma: Lymphoma is a type of blood cancer that affects the lymphatic system. It occurs when abnormal lymphocytes (a type of white blood cell) grow and divide uncontrollably. Symptoms include swollen lymph nodes, fever, weight loss, and night sweats.

There are many other types of cancer as well, each with its own unique characteristics, symptoms, and treatment options. Early detection and treatment are key to improving outcomes for people with cancer.




'''
text = cleanText(text)
findEntity(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cancer is a group of diseases characterized by the uncontrolled growth and spread of abnormal cells in the body
# <mark class="entity" style="background: #FF3355; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancer can occur in any part of the body and can spread to other parts through the blood and lymphatic systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CompositeMention</span>
# </mark>
#   There are many different types of cancer  each with its own characteristics  symptoms  and treatment options   Here are some of the most common types of cancer
# <mark class="entity" style="background: #68FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Breast Cancer
# ...

# %%
import re
def cleanText(text):
    text = re.sub(r'<category=\"(\w+)\">',' ',text)
    text = re.sub(r'</category>',' ',text)
    text = re.sub(r'[0-9]{4,}',' ',text)
    text = re.sub(r'\t',' ',text)
    text = re.sub(r'[^a-zA-Z0-9]',' ',text)
#     text = re.sub(r'[ ]{2,}',' ',text)
    text=text.strip()
    return text
#currently not eliminating numbers, we can replace it with "num" will do it later

# %%
text = '''Severe diseases are medical conditions that are characterized by significant and often life-threatening symptoms and complications. These diseases can impact various parts of the body and can have a wide range of causes, including genetic factors, infections, environmental exposures, and lifestyle factors.

Here are some examples of severe diseases:

Cancer: Cancer is a group of diseases characterized by the uncontrolled growth and spread of abnormal cells in the body. It can occur in any part of the body and can spread to other parts through the blood and lymphatic systems. Depending on the type and stage of cancer, it can be a very serious and potentially life-threatening disease.

Heart disease: Heart disease refers to a range of conditions that impact the heart, including coronary artery disease, heart failure, and arrhythmias. These conditions can cause chest pain, shortness of breath, and other symptoms, and can lead to serious complications such as heart attack and stroke.

Chronic obstructive pulmonary disease (COPD): COPD is a chronic lung disease that makes it difficult to breathe. It includes conditions such as emphysema and chronic bronchitis, and is often caused by smoking or exposure to other environmental factors. COPD can lead to severe breathing difficulties, and is a leading cause of disability and death worldwide.

Diabetes: Diabetes is a condition in which the body is unable to properly regulate blood sugar levels. It can cause a range of symptoms, including fatigue, increased thirst and urination, and blurred vision. If left untreated, diabetes can lead to serious complications such as heart disease, kidney failure, and nerve damage.

Alzheimer's disease: Alzheimer's disease is a type of dementia that affects memory, thinking, and behavior. It is characterized by the buildup of abnormal proteins in the brain, and is the most common cause of dementia in older adults. Alzheimer's disease is a progressive condition that can eventually lead to severe memory loss and loss of independence.

HIV/AIDS: HIV/AIDS is a viral infection that attacks the immune system. It is spread through sexual contact, sharing needles, or from mother to child during pregnancy, childbirth, or breastfeeding. HIV/AIDS can lead to a range of symptoms and complications, and is a leading cause of death worldwide.

Stroke: A stroke occurs when blood flow to the brain is disrupted, leading to damage to brain cells. It can cause a range of symptoms, including weakness or numbness on one side of the body, difficulty speaking or understanding speech, and vision problems. Stroke can be life-threatening, and can cause long-term disability or death.

These are just a few examples of severe diseases. Many other conditions can also be considered severe, and it is important to seek medical attention if you experience any symptoms that are concerning or unusual. Early detection and treatment can help improve outcomes and quality of life for people living with severe diseases.

'''
text = cleanText(text)
findEntity(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Severe diseases are medical conditions that are characterized by significant and often life threatening symptoms and complications  These diseases can impact various parts of the body and can have a wide range of causes  including genetic factors
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     infections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SpecificDisease</span>
# </mark>
#   environmental exposures  and lifestyle factors   Here are some examples of severe diseases
# <mark class="entity" style="background: #68FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cancer
# ...

# %%
text = ''' corruption is a cancer for any country
'''
text = cleanText(text)
findEntity(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">corruption is a cancer for any country</div></span>

# %%
text = '''Cancer is a complex and heterogeneous disease that arises from a combination of genetic and environmental factors. Despite significant progress in cancer research, it remains one of the leading causes of morbidity and mortality worldwide. Understanding the underlying mechanisms of cancer development and progression is critical for the development of effective therapies and personalized treatment strategies.

Recent advances in genomics, transcriptomics, proteomics, and metabolomics have enabled researchers to gain a better understanding of the molecular pathways that drive cancer growth and metastasis. The use of high-throughput sequencing technologies and computational approaches has facilitated the identification of cancer driver genes and the characterization of somatic mutations that contribute to tumor progression.

In addition to genetic mutations, the tumor microenvironment has emerged as a critical factor in cancer progression. The interaction between cancer cells and the surrounding stroma, including immune cells, fibroblasts, and blood vessels, plays a critical role in cancer growth and metastasis. Targeting the tumor microenvironment has shown promise as a therapeutic strategy in various cancers, including melanoma, lung cancer, and pancreatic cancer.

Immunotherapy has also emerged as a promising treatment strategy in cancer. The use of checkpoint inhibitors, which target proteins that prevent T-cell activation, has shown remarkable efficacy in various cancers, including melanoma, non-small cell lung cancer, and renal cell carcinoma. However, the response to immunotherapy varies among patients, and identifying biomarkers that predict response remains an active area of research.

Precision medicine, which involves tailoring treatment based on the individual patient's genomic profile, has shown promise in various cancers, including breast cancer, lung cancer, and melanoma. The use of next-generation sequencing technologies has enabled the identification of actionable mutations that can guide treatment decisions. However, challenges remain in implementing precision medicine in routine clinical practice, including the cost of sequencing and the need for robust evidence to support the clinical utility of genomic testing.

In conclusion, cancer research has made significant progress in recent years, with advances in genomics, immunotherapy, and precision medicine. However, challenges remain in developing effective therapies and implementing precision medicine in routine clinical practice. Continued investment in cancer research is critical to improving outcomes for cancer patients and reducing the burden of this devastating disease.




'''
text = cleanText(text)
findEntity(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Cancer is a complex and heterogeneous disease that arises from a combination of genetic and environmental factors  Despite significant progress in cancer research  it remains one of the leading causes of morbidity and mortality worldwide  Understanding the underlying mechanisms of cancer development and progression is critical for the development of effective therapies and personalized treatment strategies   Recent advances in genomics  transcriptomics  proteomics  and metabolomics have enabled researchers to gain a better understanding of the molecular pathways that drive cancer growth and metastasis  The use of high throughput sequencing technologies and computational approaches has facilitated the identification of cancer driver genes and the characterization of somatic mutations that contribute to tumor progression   In addition to genetic mutations
# ...

# %%
text = '''
9288106	Clustering of missense mutations in the <category="Modifier">ataxia-telangiectasia</category> gene in a <category="SpecificDisease">sporadic T-cell leukaemia</category>.	<category="SpecificDisease">Ataxia-telangiectasia</category> ( <category="SpecificDisease">A-T</category> ) is a <category="DiseaseClass">recessive multi-system disorder</category> caused by mutations in the ATM gene at 11q22-q23 ( ref . 3 ) . The risk of <category="DiseaseClass">cancer</category> , especially <category="DiseaseClass">lymphoid neoplasias</category> , is substantially elevated in <category="Modifier">A-T</category> patients and has long been associated with chromosomal instability . By analysing <category="Modifier">tumour</category> DNA from patients with <category="SpecificDisease">sporadic T-cell prolymphocytic leukaemia</category> ( <category="SpecificDisease">T-PLL</category> ) , a rare <category="DiseaseClass">clonal malignancy</category> with similarities to a <category="SpecificDisease">mature T-cell leukaemia</category> seen in <category="SpecificDisease">A-T</category> , we demonstrate a high frequency of ATM mutations in <category="SpecificDisease">T-PLL</category> . In marked contrast to the ATM mutation pattern in <category="SpecificDisease">A-T</category> , the most frequent nucleotide changes in this <category="DiseaseClass">leukaemia</category> were missense mutations . These clustered in the region corresponding to the kinase domain , which is highly conserved in ATM-related proteins in mouse , yeast and Drosophila . The resulting amino-acid substitutions are predicted to interfere with ATP binding or substrate recognition . Two of seventeen mutated <category="SpecificDisease">T-PLL</category> samples had a previously reported <category="Modifier">A-T</category> allele . In contrast , no mutations were detected in the p53 gene , suggesting that this <category="Modifier">tumour</category> suppressor is not frequently altered in this <category="DiseaseClass">leukaemia</category> . Occasional missense mutations in ATM were also found in <category="Modifier">tumour</category> DNA from patients with <category="SpecificDisease">B-cell non-Hodgkins lymphomas</category> ( <category="SpecificDisease">B-NHL</category> ) and a <category="Modifier">B-NHL</category> cell line . The evidence of a significant proportion of loss-of-function mutations and a complete absence of the normal copy of ATM in the majority of mutated <category="DiseaseClass">tumours</category> establishes somatic inactivation of this gene in the pathogenesis of <category="SpecificDisease">sporadic T-PLL</category> and suggests that ATM acts as a <category="Modifier">tumour</category> suppressor . As constitutional DNA was not available , a putative hereditary predisposition to <category="SpecificDisease">T-PLL</category> will require further investigation . . 
'''
text = cleanText(text)
findEntity(text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Clustering of missense mutations in the
# <mark class="entity" style="background: #68FF33; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ataxia telangiectasia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Modifier</span>
# </mark>
#   gene in a
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sporadic T cell leukaemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SpecificDisease</span>
# </mark>
#
# <mark class="entity" style="background: #F67DE3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ataxia telangiectasia
# ...
